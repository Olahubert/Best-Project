# %%
import pandas as pd

# %%
pd.read_csv ('../2nd_lesson/sales.csv ')
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
pd.read_excel ("Customer.xlsx")
# Out:
#    Customer ID     Name                    Email         City
# 0            1     John         john@hotmail.com      Houston
# 1            2     Fodd        fodd2@hotmail.com      Houston
# 2            3  Richard        mozmill@yahoo.com      Seattle
# 3            4     Mary        marie@hotmail.com     New York
# 4            5      Ben        richkid@gmail.com      Atlanta
# 5            6    Moses         mosiah@yahoo.com       Dallas
# 6            7   Lizzie  lizzieonye234@yahoo.com      Chicago
# 7            8    Peter       peterson@gmail.com  Los Angeles
# 8            9    Jason   jackiechan@hotmail.com       Denver
# 9           10    Sansa       sansie@hotmail.com      Phoenix

# %%
customers_df=pd.read_excel ("Customer.xlsx")

# %%
from sqlalchemy import create_engine

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
engine = create_engine('postgresql+psycopg2://postgres:Olawale@localhost/ecommerce_db')

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/ecommerce_db)

# %%
pd.read_excel ("Customer.xlsx")
# Out:
#    Customer ID     Name                    Email         City
# 0            1     John         john@hotmail.com      Houston
# 1            2     Fodd        fodd2@hotmail.com      Houston
# 2            3  Richard        mozmill@yahoo.com      Seattle
# 3            4     Mary        marie@hotmail.com     New York
# 4            5      Ben        richkid@gmail.com      Atlanta
# 5            6    Moses         mosiah@yahoo.com       Dallas
# 6            7   Lizzie  lizzieonye234@yahoo.com      Chicago
# 7            8    Peter       peterson@gmail.com  Los Angeles
# 8            9    Jason   jackiechan@hotmail.com       Denver
# 9           10    Sansa       sansie@hotmail.com      Phoenix

# %%
pwd
# Out:
# 'C:\\Users\\visit\\OneDrive\\Desktop\\Data Analysis\\First lesson'

# %%
pd.read_excel ("pandas_Order.xlsx")
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price
# 0          1            1         101         2 2024-01-10     10
# 1          2            4         102         1 2024-01-12     20
# 2          3            7         103         3 2024-01-15     30
# 3          4            1         104         1 2024-01-18     40
# 4          5            6         105         2 2024-01-20     20
# 5          6            5         106         1 2024-02-10     50
# 6          7            2         107         4 2024-02-12     10
# 7          8           10         108         2 2024-02-15     60
# 8          9            4         109         3 2024-02-18     20
# 9         10            3         110         1 2024-02-20     70
# 10        11            9         111         2 2024-02-29     40
# 11        12            2         112         2 2024-01-10     30
# 12        13            8         113         1 2024-01-22     20
# ...

# %%
orders_df=pd.read_excel ("pandas_Order.xlsx")

# %%
orders_df
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price
# 0          1            1         101         2 2024-01-10     10
# 1          2            4         102         1 2024-01-12     20
# 2          3            7         103         3 2024-01-15     30
# 3          4            1         104         1 2024-01-18     40
# 4          5            6         105         2 2024-01-20     20
# 5          6            5         106         1 2024-02-10     50
# 6          7            2         107         4 2024-02-12     10
# 7          8           10         108         2 2024-02-15     60
# 8          9            4         109         3 2024-02-18     20
# 9         10            3         110         1 2024-02-20     70
# 10        11            9         111         2 2024-02-29     40
# 11        12            2         112         2 2024-01-10     30
# 12        13            8         113         1 2024-01-22     20
# ...

# %%
orders_df.Price.sum()
# Out:
# 565

# %%
orders_df.sort_values(by=['Price','Customer ID'],ascending=False)
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price
# 14        15            4         115         4 2024-01-09     80
# 9         10            3         110         1 2024-02-20     70
# 13        14            7         114         3 2024-01-25     65
# 7          8           10         108         2 2024-02-15     60
# 5          6            5         106         1 2024-02-10     50
# 10        11            9         111         2 2024-02-29     40
# 3          4            1         104         1 2024-01-18     40
# 2          3            7         103         3 2024-01-15     30
# 11        12            2         112         2 2024-01-10     30
# 12        13            8         113         1 2024-01-22     20
# 4          5            6         105         2 2024-01-20     20
# 1          2            4         102         1 2024-01-12     20
# 8          9            4         109         3 2024-02-18     20
# ...

# %%
Most_money=orders_df.sort_values(by=['Price','Customer ID'],ascending=False)

# %%
Most_money.head(10)
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price
# 14        15            4         115         4 2024-01-09     80
# 9         10            3         110         1 2024-02-20     70
# 13        14            7         114         3 2024-01-25     65
# 7          8           10         108         2 2024-02-15     60
# 5          6            5         106         1 2024-02-10     50
# 10        11            9         111         2 2024-02-29     40
# 3          4            1         104         1 2024-01-18     40
# 2          3            7         103         3 2024-01-15     30
# 11        12            2         112         2 2024-01-10     30
# 12        13            8         113         1 2024-01-22     20

# %%
orders_df['Price'].sum()
# Out:
# 565

# %%
orders_df.Quantity.sum()
# Out:
# 32

# %%
orders_df[['Quantity','Product ID']]
# Out:
#     Quantity  Product ID
# 0          2         101
# 1          1         102
# 2          3         103
# 3          1         104
# 4          2         105
# 5          1         106
# 6          4         107
# 7          2         108
# 8          3         109
# 9          1         110
# 10         2         111
# 11         2         112
# 12         1         113
# 13         3         114
# 14         4         115

# %%
Total_Quantity_sold=orders_df[['Quantity','Product ID']]

# %%
orders_df.Quantity.sort_values(ascending = False)
# Out:
# 6     4
# 14    4
# 2     3
# 8     3
# 13    3
# 0     2
# 4     2
# 7     2
# 10    2
# 11    2
# 1     1
# 3     1
# 5     1
# 9     1
# 12    1
# Name: Quantity, dtype: int64

# %%
Quantity_sold=orders_df.Quantity.sort_values(ascending = False)

# %%
Quantity_sold.head(5)
# Out:
# 6     4
# 14    4
# 2     3
# 8     3
# 13    3
# Name: Quantity, dtype: int64

# %%
TOP_5_Quantity=Quantity_sold.head(5)

# %%
merged_df = pd.merge(orders_df, customers_df, on='Customer ID', how='inner')

# %% [markdown]
# merged_df

# %%
print(merged_df)
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price     Name  \
# 0          1            1         101         2 2024-01-10     10     John
# 1          4            1         104         1 2024-01-18     40     John
# 2          2            4         102         1 2024-01-12     20     Mary
# 3          9            4         109         3 2024-02-18     20     Mary
# 4         15            4         115         4 2024-01-09     80     Mary
# 5          3            7         103         3 2024-01-15     30   Lizzie
# 6         14            7         114         3 2024-01-25     65   Lizzie
# 7          5            6         105         2 2024-01-20     20    Moses
# 8          6            5         106         1 2024-02-10     50      Ben
# 9          7            2         107         4 2024-02-12     10     Fodd
# 10        12            2         112         2 2024-01-10     30     Fodd
# ...

# %%
merged_df.sort_values(by=['Name','Customer ID'],ascending=True)
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price     Name  \
# 8          6            5         106         1 2024-02-10     50      Ben
# 9          7            2         107         4 2024-02-12     10     Fodd
# 10        12            2         112         2 2024-01-10     30     Fodd
# 13        11            9         111         2 2024-02-29     40    Jason
# 0          1            1         101         2 2024-01-10     10     John
# 1          4            1         104         1 2024-01-18     40     John
# 5          3            7         103         3 2024-01-15     30   Lizzie
# 6         14            7         114         3 2024-01-25     65   Lizzie
# 2          2            4         102         1 2024-01-12     20     Mary
# 3          9            4         109         3 2024-02-18     20     Mary
# 4         15            4         115         4 2024-01-09     80     Mary
# ...

# %%
grouped_ascend=merged_df.sort_values(by=['Name','Customer ID'],ascending=True)

# %%
grouped_ascend
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price     Name  \
# 8          6            5         106         1 2024-02-10     50      Ben
# 9          7            2         107         4 2024-02-12     10     Fodd
# 10        12            2         112         2 2024-01-10     30     Fodd
# 13        11            9         111         2 2024-02-29     40    Jason
# 0          1            1         101         2 2024-01-10     10     John
# 1          4            1         104         1 2024-01-18     40     John
# 5          3            7         103         3 2024-01-15     30   Lizzie
# 6         14            7         114         3 2024-01-25     65   Lizzie
# 2          2            4         102         1 2024-01-12     20     Mary
# 3          9            4         109         3 2024-02-18     20     Mary
# 4         15            4         115         4 2024-01-09     80     Mary
# ...

# %%
grouped_ascend
# Out:
#     Order ID  Customer ID  Product ID  Quantity Order Date  Price     Name  \
# 8          6            5         106         1 2024-02-10     50      Ben
# 9          7            2         107         4 2024-02-12     10     Fodd
# 10        12            2         112         2 2024-01-10     30     Fodd
# 13        11            9         111         2 2024-02-29     40    Jason
# 0          1            1         101         2 2024-01-10     10     John
# 1          4            1         104         1 2024-01-18     40     John
# 5          3            7         103         3 2024-01-15     30   Lizzie
# 6         14            7         114         3 2024-01-25     65   Lizzie
# 2          2            4         102         1 2024-01-12     20     Mary
# 3          9            4         109         3 2024-02-18     20     Mary
# 4         15            4         115         4 2024-01-09     80     Mary
# ...

# %%
Jone_profile=grouped_ascend['Name'].isin(['Mary']).any()

# %%
print(Jone_profile)
# Out:
# True

# %%
grouped_name

# %%
print(grouped_name)

# %%
Name_by_customer_id = grouped_name.groupby('Name')['Customer ID'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 Name_by_customer_id = grouped_name.groupby('Name')['Customer ID'].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
merged_df.sort_values(by='Name', inplace=True)

# %%
by_name=merged_df.sort_values(by='Name', inplace=True)

# %%
by_name

# %%
print(by_name)
# Out:
# None
