# %%
import pandas as pd

# %%
pd.read_csv("sales.csv")
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department=pd.read_csv("sales.csv")

# %%
Sales_department
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department.sort_values(by="Profit")
# Out:
#             State  Total Expenses     Product  Sales   Market Size  Profit  \
# 2042       Nevada           147.0   Green Tea   20.0  Small Market  -638.0
# 2044       Nevada           145.0   Green Tea   33.0  Small Market  -605.0
# 2041       Nevada           131.0   Green Tea   21.0  Small Market  -558.0
# 2036       Nevada           132.0   Green Tea   19.0  Small Market  -552.0
# 1922       Nevada           131.0   Green Tea   28.0  Small Market  -542.0
# ...           ...             ...         ...    ...           ...     ...
# 62     California            35.0  Darjeeling  213.0  Major Market     NaN
# 73     California           149.0   Columbian  745.0  Major Market     NaN
# 153    California            96.0       Lemon  559.0  Major Market     NaN
# 298      Colorado            27.0   Green Tea  112.0  Major Market     NaN
# 703   Connecticut            36.0        Mint  131.0  Small Market     NaN
#
#        Market  Marketing Product Type  Inventory     Type
# ...

# %%
Sales_department.sort_values(by=["Sales","Marketing"])
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 1914      Nevada           126.0       Green Tea   17.0  Small Market  -354.0
# 1917      Nevada           133.0       Green Tea   18.0  Small Market  -380.0
# 1923      Nevada           124.0       Green Tea   18.0  Small Market  -524.0
# 2036      Nevada           132.0       Green Tea   19.0  Small Market  -552.0
# 2034      Nevada           147.0       Green Tea   19.0  Small Market  -430.0
# ...          ...             ...             ...    ...           ...     ...
# 2645    New York           178.0       Columbian  910.0  Major Market   368.0
# 157   California           178.0       Columbian  912.0  Major Market   370.0
# 2644    New York           178.0       Columbian  912.0  Major Market   370.0
# 502     Colorado            54.0  Decaf Espresso    NaN  Major Market    80.0
# 508     Colorado            71.0       Chamomile    NaN  Major Market    99.0
#
# ...

# %%
Sales_department.sort_values(by=["Sales","Marketing"], ascending = False)
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 157   California           178.0       Columbian  912.0  Major Market   370.0
# 2644    New York           178.0       Columbian  912.0  Major Market   370.0
# 131   California           178.0       Columbian  910.0  Major Market   368.0
# 2645    New York           178.0       Columbian  910.0  Major Market   368.0
# 132   California           166.0       Columbian  904.0  Major Market   511.0
# ...          ...             ...             ...    ...           ...     ...
# 1917      Nevada           133.0       Green Tea   18.0  Small Market  -380.0
# 1923      Nevada           124.0       Green Tea   18.0  Small Market  -524.0
# 1914      Nevada           126.0       Green Tea   17.0  Small Market  -354.0
# 508     Colorado            71.0       Chamomile    NaN  Major Market    99.0
# 502     Colorado            54.0  Decaf Espresso    NaN  Major Market    80.0
#
# ...

# %%
Sales_department.sort_values(by="Profit",ascending = False)
# Out:
#               State  Total Expenses           Product  Sales   Market Size  \
# 1659  Massachusetts            46.0         Columbian  659.0  Major Market
# 1590  Massachusetts            46.0         Columbian  658.0  Major Market
# 1604  Massachusetts            45.0         Columbian  643.0  Major Market
# 1605  Massachusetts            51.0         Columbian  614.0  Major Market
# 2500       New York            91.0  Regular Espresso  815.0  Major Market
# ...             ...             ...               ...    ...           ...
# 62       California            35.0        Darjeeling  213.0  Major Market
# 73       California           149.0         Columbian  745.0  Major Market
# 153      California            96.0             Lemon  559.0  Major Market
# 298        Colorado            27.0         Green Tea  112.0  Major Market
# 703     Connecticut            36.0              Mint  131.0  Small Market
#
#       Profit   Market  Marketing Product Type  Inventory     Type
# ...

# %%
Sales_department.Market
# Out:
# 0          West
# 1          West
# 2          West
# 3          West
# 4          West
#          ...
# 4236    Central
# 4237    Central
# 4238    Central
# 4239    Central
# 4240    Central
# Name: Market, Length: 4241, dtype: object

# %%
Sales_department.Market.sort_values()
# Out:
# 4240    Central
# 1224    Central
# 1223    Central
# 1222    Central
# 1221    Central
#          ...
# 2142       West
# 2141       West
# 2140       West
# 2150       West
# 2120       West
# Name: Market, Length: 4241, dtype: object

# %%
Sales_department.Market.sort_values(ascending = False)
# Out:
# 0          West
# 3148       West
# 3162       West
# 3161       West
# 3160       West
#          ...
# 993     Central
# 994     Central
# 995     Central
# 996     Central
# 4240    Central
# Name: Market, Length: 4241, dtype: object

# %%
Sales_department.sort_index(ascending = False)
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# ...          ...             ...             ...    ...           ...     ...
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
#
# ...

# %%
Sales_department.sort_index()
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department.to_csv("Sales Departmet.csv")
