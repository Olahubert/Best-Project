# %%
import pandas as pd

# %%
pd.read_csv("sales.csv")
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department=pd.read_csv("sales.csv")

# %%
(Sales_department)
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department.head(20)
# Out:
#          State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0   California            63.0        Amaretto  109.0  Major Market  -131.0
# 1   California            55.0       Green Tea  201.0  Major Market    88.0
# 2   California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3   California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4   California            37.0       Chamomile  247.0  Major Market   148.0
# 5   California            99.0           Lemon  582.0  Major Market   291.0
# 6   California            25.0            Mint   90.0  Major Market    26.0
# 7   California            43.0      Darjeeling  276.0  Major Market   120.0
# 8   California            32.0       Earl Grey  187.0  Major Market    79.0
# 9   California           142.0       Columbian  687.0  Major Market   364.0
# 10  California           166.0       Columbian  902.0  Major Market   508.0
# ...

# %%
Sales_department.tail(20)
# Out:
#           State  Total Expenses         Product  Sales   Market Size  Profit  \
# 4221  Wisconsin            29.0  Decaf Espresso  115.0  Small Market    36.0
# 4222  Wisconsin            26.0  Decaf Espresso  110.0  Small Market    47.0
# 4223  Wisconsin            19.0  Decaf Espresso   55.0  Small Market    16.0
# 4224  Wisconsin            36.0       Chamomile  104.0  Small Market    29.0
# 4225  Wisconsin            41.0       Chamomile  151.0  Small Market    53.0
# 4226  Wisconsin            40.0       Chamomile  141.0  Small Market    48.0
# 4227  Wisconsin            36.0       Chamomile  107.0  Small Market    30.0
# 4228  Wisconsin            42.0       Chamomile  178.0  Small Market    93.0
# 4229  Wisconsin            36.0       Chamomile  114.0  Small Market    45.0
# 4230  Wisconsin            27.0           Lemon  144.0  Small Market    58.0
# 4231  Wisconsin            25.0           Lemon  123.0  Small Market    64.0
# ...

# %%
Sales_department.shape
# Out:
# (4241, 11)

# %%
type(Sales_department)
# Out:
# pandas.core.frame.DataFrame

# %%
Sales_department.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4241 entries, 0 to 4240
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           4241 non-null   object
#  1   Total Expenses  4238 non-null   float64
#  2   Product         4241 non-null   object
#  3   Sales           4239 non-null   float64
#  4   Market Size     4241 non-null   object
#  5   Profit          4235 non-null   float64
#  6   Market          4241 non-null   object
#  7   Marketing       4241 non-null   int64
#  8   Product Type    4241 non-null   object
#  9   Inventory       4240 non-null   float64
#  10  Type            4241 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 364.6+ KB

# %%
Sales_department.describe()
# Out:
#        Total Expenses        Sales       Profit    Marketing    Inventory
# count     4238.000000  4239.000000  4235.000000  4241.000000  4240.000000
# mean        53.989146   192.567351    60.840614    31.124499   747.971226
# std         32.295812   150.563621   101.301672    26.983618   660.498475
# min         10.000000    17.000000  -638.000000     0.000000 -3534.000000
# 25%         33.000000   100.000000    17.000000    13.000000   431.500000
# 50%         46.000000   138.000000    40.000000    22.000000   619.000000
# 75%         65.000000   230.000000    92.000000    39.000000   901.000000
# max        190.000000   912.000000   778.000000   156.000000  8252.000000

# %%
Names=["Olawale","Miracle","Adebayo","Arise","Sunday","Shantell"]

# %%
pd.DataFrame(Names, columns = ["first_name"])
# Out:
#   first_name
# 0    Olawale
# 1    Miracle
# 2    Adebayo
# 3      Arise
# 4     Sunday
# 5   Shantell

# %%
state={"Lagos":["Ikeja"],"Oyo":["Ibadan"],"Ondo":["Akure"],"Edo":["Benin"]}

# %%
pd.DataFrame(state)
# Out:
#    Lagos     Oyo   Ondo    Edo
# 0  Ikeja  Ibadan  Akure  Benin

# %%
animals = {"mammals": ["cow","goat","dog","lion"], "Reptiles": ["Lizard","snake","Tortoise","crocodile"], "Insects": ["Ant","fly","bees","bug"]}

# %%
Animal_kingdom=pd.DataFrame(animals)

# %%
Animal_kingdom
# Out:
#   mammals   Reptiles Insects
# 0     cow     Lizard     Ant
# 1    goat      snake     fly
# 2     dog   Tortoise    bees
# 3    lion  crocodile     bug

# %%
Animal_kingdom.set_index("mammals", inplace=True)

# %%
Animal_kingdom
# Out:
#           Reptiles Insects
# mammals
# cow         Lizard     Ant
# goat         snake     fly
# dog       Tortoise    bees
# lion     crocodile     bug

# %%
Animal_kingdom.Reptiles
# Out:
# mammals
# cow        Lizard
# goat        snake
# dog      Tortoise
# lion    crocodile
# Name: Reptiles, dtype: object

# %%
Animal_kingdom['Reptiles']
# Out:
# mammals
# cow        Lizard
# goat        snake
# dog      Tortoise
# lion    crocodile
# Name: Reptiles, dtype: object

# %%
Sales_department.Sales
# Out:
# 0       109.0
# 1       201.0
# 2       289.0
# 3       576.0
# 4       247.0
#         ...
# 4236     90.0
# 4237    113.0
# 4238    150.0
# 4239    131.0
# 4240    165.0
# Name: Sales, Length: 4241, dtype: float64

# %%
Sales_column=Sales_department.Sales

# %%
Sales_column.head(10)
# Out:
# 0    109.0
# 1    201.0
# 2    289.0
# 3    576.0
# 4    247.0
# 5    582.0
# 6     90.0
# 7    276.0
# 8    187.0
# 9    687.0
# Name: Sales, dtype: float64

# %%
type(Sales_column)
# Out:
# pandas.core.series.Series

# %%
Sales_department.iloc[0]
# Out:
# State               California
# Total Expenses            63.0
# Product               Amaretto
# Sales                    109.0
# Market Size       Major Market
# Profit                  -131.0
# Market                    West
# Marketing                   40
# Product Type            Coffee
# Inventory               2947.0
# Type                   Regular
# Name: 0, dtype: object

# %%
Sales_row=Sales_department.iloc[0]

# %%
type(Sales_row)
# Out:
# pandas.core.series.Series

# %%
Animal_kingdom.loc["cow"]
# Out:
# Reptiles    Lizard
# Insects        Ant
# Name: cow, dtype: object

# %%
Animal_kingdom.loc["goat"]
# Out:
# Reptiles    snake
# Insects       fly
# Name: goat, dtype: object

# %%
Sales_department.iloc[[0,3,4,7,8,9]]
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
# 7  California            43.0      Darjeeling  276.0  Major Market   120.0
# 8  California            32.0       Earl Grey  187.0  Major Market    79.0
# 9  California           142.0       Columbian  687.0  Major Market   364.0
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf
# 7   West         31          Tea      897.0  Regular
# 8   West         21          Tea      580.0  Regular
# 9   West         90       Coffee     2067.0  Regular

# %%
Animal_kingdom.loc[["cow","lion","dog","goat"]]
# Out:
#           Reptiles Insects
# mammals
# cow         Lizard     Ant
# lion     crocodile     bug
# dog       Tortoise    bees
# goat         snake     fly

# %%
Animal_kingdom[["Insects", "Reptiles"]]
# Out:
#         Insects   Reptiles
# mammals
# cow         Ant     Lizard
# goat        fly      snake
# dog        bees   Tortoise
# lion        bug  crocodile

# %%
var = ["Reptiles", "Insects"]
Animal_kingdom[var]
# Out:
#           Reptiles Insects
# mammals
# cow         Lizard     Ant
# goat         snake     fly
# dog       Tortoise    bees
# lion     crocodile     bug

# %%
Animal_kingdom.var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of           Reptiles Insects
# mammals
# cow         Lizard     Ant
# goat         snake     fly
# dog       Tortoise    bees
# lion     crocodile     bug>

# %%
Scores = [10,35,50,80,100]

# %%
pd.DataFrame(Scores)
# Out:
#      0
# 0   10
# 1   35
# 2   50
# 3   80
# 4  100

# %%
Scores
# Out:
# [10, 35, 50, 80, 100]

# %%
Sales_department
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department["Product"]
# Out:
# 0             Amaretto
# 1            Green Tea
# 2          Caffe Mocha
# 3       Decaf Espresso
# 4            Chamomile
#              ...
# 4236        Darjeeling
# 4237        Darjeeling
# 4238         Earl Grey
# 4239         Earl Grey
# 4240         Earl Grey
# Name: Product, Length: 4241, dtype: object

# %%
Sales_department.Product
# Out:
# 0             Amaretto
# 1            Green Tea
# 2          Caffe Mocha
# 3       Decaf Espresso
# 4            Chamomile
#              ...
# 4236        Darjeeling
# 4237        Darjeeling
# 4238         Earl Grey
# 4239         Earl Grey
# 4240         Earl Grey
# Name: Product, Length: 4241, dtype: object

# %%
Sales_department["Product","Sales","Profit"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Product', 'Sales', 'Profit')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
Productivity=["Product","Sales","Profit"]

# %%
Sales_department[Productivity]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 Sales_department[Productivity]
#
# NameError: name 'Productivity' is not defined

# %%
greaterthan_300 =(Sales_department['Sales'] > 300)

# %%
greaterthan_300
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# 4240    False
# Name: Sales, Length: 4241, dtype: bool

# %%
Sales_department.iloc[0]
# Out:
# State               California
# Total Expenses            63.0
# Product               Amaretto
# Sales                    109.0
# Market Size       Major Market
# Profit                  -131.0
# Market                    West
# Marketing                   40
# Product Type            Coffee
# Inventory               2947.0
# Type                   Regular
# Name: 0, dtype: object

# %%
Sales_department.iloc[[1,2,3]]
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
#
#   Market  Marketing Product Type  Inventory     Type
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf

# %%
Sales_department.loc[greaterthan_300]
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 5     California            99.0           Lemon  582.0  Major Market   291.0
# 9     California           142.0       Columbian  687.0  Major Market   364.0
# 10    California           166.0       Columbian  902.0  Major Market   508.0
# 11    California           139.0       Columbian  664.0  Major Market   349.0
# ...          ...             ...             ...    ...           ...     ...
# 3932  Washington            71.0       Chamomile  329.0  Small Market   171.0
# 3933  Washington            73.0       Chamomile  334.0  Small Market   171.0
# 4004  Washington            75.0       Chamomile  347.0  Small Market   179.0
# 4122   Wisconsin           149.0       Columbian  317.0  Small Market    35.0
# 4213   Wisconsin           139.0       Columbian  314.0  Small Market    48.0
#
# ...

# %%
Sales_department["Sales"].unique()
# Out:
# array([109., 201., 289., 576., 247., 582.,  90., 276., 187., 687., 902.,
#        664., 168., 546., 589., 567., 198., 467., 490., 119., 290., 527.,
#        132., 159., 607., 452., 120., 188., 256., 302., 322., 245., 509.,
#        531., 298., 318., 604., 498.,  98., 106., 510., 135., 384., 249.,
#        190., 202., 142., 645., 169., 180., 170., 131., 626., 637., 261.,
#        525., 486., 213., 230., 521., 194., 179., 234., 522., 227., 516.,
#        882., 745., 165., 160., 412., 280., 343., 628., 506.,  96., 254.,
#        210., 678., 496., 507., 423.,  87., 117., 842., 182., 387., 634.,
#        672., 520., 193., 208., 478., 116., 181., 309., 219., 133., 487.,
#        141., 790., 650., 166., 156., 612., 243., 199.,  95., 756., 910.,
#        904., 118., 127., 139., 189., 130., 342., 262., 134., 123., 212.,
#         86., 301., 265., 532., 559., 456., 675., 912., 699., 749., 286.,
#        581.,  92., 150., 211., 228., 163., 192., 345., 598., 465., 562.,
# ...

# %%
Sales_department["State"].unique()
# Out:
# array(['California', 'Colorado', 'Connecticut', 'Florida', 'Illinois',
#        'Iowa', 'Louisiana', 'Massachusetts', 'Missouri', 'Nevada',
#        'New Hampshire', 'New Mexico', 'New York', 'Ohio', 'Oklahoma',
#        'Oregon', 'Texas', 'Utah', 'Washington', 'Wisconsin'], dtype=object)

# %%
rt_state = ["California", "Texas"]

# %%
Sales_department["State"].isin(rt_state)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# 4240    False
# Name: State, Length: 4241, dtype: bool

# %%
South_states=Sales_department["State"].isin(rt_state)

# %%
South_states
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# 4240    False
# Name: State, Length: 4241, dtype: bool

# %%
Sales_department
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales_department.loc[South_states]
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 3492       Texas           117.0       Columbian  678.0  Major Market   250.0
# 3493       Texas            37.0     Caffe Mocha  254.0  Major Market   155.0
# 3494       Texas            33.0  Decaf Espresso  199.0  Major Market    85.0
# 3495       Texas            33.0           Lemon   92.0  Major Market    28.0
# 3496       Texas            54.0     Caffe Latte  192.0  Major Market    80.0
#
# ...

# %%
Sales_department.columns
# Out:
# Index(['State', 'Total Expenses', 'Product', 'Sales', 'Market Size', 'Profit',
#        'Market', 'Marketing', 'Product Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
Sales_department.columns.str.replace(' ','_')
# Out:
# Index(['State', 'Total_Expenses', 'Product', 'Sales', 'Market_Size', 'Profit',
#        'Market', 'Marketing', 'Product_Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
Sales_department.head(10)
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
# 5  California            99.0           Lemon  582.0  Major Market   291.0
# 6  California            25.0            Mint   90.0  Major Market    26.0
# 7  California            43.0      Darjeeling  276.0  Major Market   120.0
# 8  California            32.0       Earl Grey  187.0  Major Market    79.0
# 9  California           142.0       Columbian  687.0  Major Market   364.0
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# ...

# %%
Sales_department2=Sales_department.columns.str.replace(' ','_')

# %%
Sales_department2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 Sales_department2.head()
#
# AttributeError: 'Index' object has no attribute 'head'

# %%
Sales_department2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 Sales_department2.head()
#
# AttributeError: 'Index' object has no attribute 'head'

# %%
Sales_department.rename(columns = {"Sales": "New_Sales"}, inplace = True)

# %%
Sales_department.New_Sales
# Out:
# 0       109.0
# 1       201.0
# 2       289.0
# 3       576.0
# 4       247.0
#         ...
# 4236     90.0
# 4237    113.0
# 4238    150.0
# 4239    131.0
# 4240    165.0
# Name: New_Sales, Length: 4241, dtype: float64

# %%
Sales_department.rename(columns = {"Product":"New_Product"}, inplace = True)

# %%
Sales_department.New_Product
# Out:
# 0             Amaretto
# 1            Green Tea
# 2          Caffe Mocha
# 3       Decaf Espresso
# 4            Chamomile
#              ...
# 4236        Darjeeling
# 4237        Darjeeling
# 4238         Earl Grey
# 4239         Earl Grey
# 4240         Earl Grey
# Name: New_Product, Length: 4241, dtype: object

# %%
Sales_department
# Out:
#            State  Total Expenses     New_Product  New_Sales   Market Size  \
# 0     California            63.0        Amaretto      109.0  Major Market
# 1     California            55.0       Green Tea      201.0  Major Market
# 2     California           143.0     Caffe Mocha      289.0  Major Market
# 3     California           113.0  Decaf Espresso      576.0  Major Market
# 4     California            37.0       Chamomile      247.0  Major Market
# ...          ...             ...             ...        ...           ...
# 4236   Wisconsin            34.0      Darjeeling       90.0  Small Market
# 4237   Wisconsin            36.0      Darjeeling      113.0  Small Market
# 4238   Wisconsin            86.0       Earl Grey      150.0  Small Market
# 4239   Wisconsin            79.0       Earl Grey      131.0  Small Market
# 4240   Wisconsin            87.0       Earl Grey      165.0  Small Market
#
#       Profit   Market  Marketing Product Type  Inventory     Type
# ...

# %%
Sales_department.loc[0,"Total Expenses"] = 56.2

# %%
Sales_department.iloc[0]
# Out:
# State               California
# Total Expenses            56.2
# New_Product           Amaretto
# New_Sales                109.0
# Market Size       Major Market
# Profit                  -131.0
# Market                    West
# Marketing                   40
# Product Type            Coffee
# Inventory               2947.0
# Type                   Regular
# Name: 0, dtype: object

# %%
Sales_department.New_Sales + Sales_department.Profit
# Out:
# 0       -22.0
# 1       289.0
# 2       314.0
# 3       792.0
# 4       395.0
#         ...
# 4236    110.0
# 4237    144.0
# 4238    151.0
# 4239    128.0
# 4240    169.0
# Length: 4241, dtype: float64

# %%
Sales_department.Profit.sum()
# Out:
# 257734.0

# %%
Sales_department.State +" "+ Sales_department.Market
# Out:
# 0         California West
# 1         California West
# 2         California West
# 3         California West
# 4         California West
#               ...
# 4236    Wisconsin Central
# 4237    Wisconsin Central
# 4238    Wisconsin Central
# 4239    Wisconsin Central
# 4240    Wisconsin Central
# Length: 4241, dtype: object

# %%
Sales_department.drop(columns= ['New_Product'], inplace=True)

# %%
Sales_department
# Out:
#            State  Total Expenses  New_Sales   Market Size  Profit   Market  \
# 0     California            56.2      109.0  Major Market  -131.0     West
# 1     California            55.0      201.0  Major Market    88.0     West
# 2     California           143.0      289.0  Major Market    25.0     West
# 3     California           113.0      576.0  Major Market   216.0     West
# 4     California            37.0      247.0  Major Market   148.0     West
# ...          ...             ...        ...           ...     ...      ...
# 4236   Wisconsin            34.0       90.0  Small Market    20.0  Central
# 4237   Wisconsin            36.0      113.0  Small Market    31.0  Central
# 4238   Wisconsin            86.0      150.0  Small Market     1.0  Central
# 4239   Wisconsin            79.0      131.0  Small Market    -3.0  Central
# 4240   Wisconsin            87.0      165.0  Small Market     4.0  Central
#
#       Marketing Product Type  Inventory     Type
# ...

# %%
Sales_department.drop(index=0 , inplace=True)

# %%
Sales_department
# Out:
#            State  Total Expenses  New_Sales   Market Size  Profit   Market  \
# 1     California            55.0      201.0  Major Market    88.0     West
# 2     California           143.0      289.0  Major Market    25.0     West
# 3     California           113.0      576.0  Major Market   216.0     West
# 4     California            37.0      247.0  Major Market   148.0     West
# 5     California            99.0      582.0  Major Market   291.0     West
# ...          ...             ...        ...           ...     ...      ...
# 4236   Wisconsin            34.0       90.0  Small Market    20.0  Central
# 4237   Wisconsin            36.0      113.0  Small Market    31.0  Central
# 4238   Wisconsin            86.0      150.0  Small Market     1.0  Central
# 4239   Wisconsin            79.0      131.0  Small Market    -3.0  Central
# 4240   Wisconsin            87.0      165.0  Small Market     4.0  Central
#
#       Marketing Product Type  Inventory     Type
# ...

# %%
Sales_department.rename(columns = {"Marketing": "Trade"}, inplace=True)

# %%
Sales_department
# Out:
#            State  Total Expenses  New_Sales   Market Size  Profit   Market  \
# 1     California            55.0      201.0  Major Market    88.0     West
# 2     California           143.0      289.0  Major Market    25.0     West
# 3     California           113.0      576.0  Major Market   216.0     West
# 4     California            37.0      247.0  Major Market   148.0     West
# 5     California            99.0      582.0  Major Market   291.0     West
# ...          ...             ...        ...           ...     ...      ...
# 4236   Wisconsin            34.0       90.0  Small Market    20.0  Central
# 4237   Wisconsin            36.0      113.0  Small Market    31.0  Central
# 4238   Wisconsin            86.0      150.0  Small Market     1.0  Central
# 4239   Wisconsin            79.0      131.0  Small Market    -3.0  Central
# 4240   Wisconsin            87.0      165.0  Small Market     4.0  Central
#
#       Trade Product Type  Inventory     Type
# ...

# %%
Sales_department.drop(columns=["Type"],inplace=True)

# %%
Sales_department
# Out:
#            State  Total Expenses  New_Sales   Market Size  Profit   Market  \
# 1     California            55.0      201.0  Major Market    88.0     West
# 2     California           143.0      289.0  Major Market    25.0     West
# 3     California           113.0      576.0  Major Market   216.0     West
# 4     California            37.0      247.0  Major Market   148.0     West
# 5     California            99.0      582.0  Major Market   291.0     West
# ...          ...             ...        ...           ...     ...      ...
# 4236   Wisconsin            34.0       90.0  Small Market    20.0  Central
# 4237   Wisconsin            36.0      113.0  Small Market    31.0  Central
# 4238   Wisconsin            86.0      150.0  Small Market     1.0  Central
# 4239   Wisconsin            79.0      131.0  Small Market    -3.0  Central
# 4240   Wisconsin            87.0      165.0  Small Market     4.0  Central
#
#       Trade Product Type  Inventory
# ...

# %%
Sales_department.drop(index=4000 ,inplace=True)

# %%
Sales_department
# Out:
#            State  Total Expenses  New_Sales   Market Size  Profit   Market  \
# 1     California            55.0      201.0  Major Market    88.0     West
# 2     California           143.0      289.0  Major Market    25.0     West
# 3     California           113.0      576.0  Major Market   216.0     West
# 4     California            37.0      247.0  Major Market   148.0     West
# 5     California            99.0      582.0  Major Market   291.0     West
# ...          ...             ...        ...           ...     ...      ...
# 4236   Wisconsin            34.0       90.0  Small Market    20.0  Central
# 4237   Wisconsin            36.0      113.0  Small Market    31.0  Central
# 4238   Wisconsin            86.0      150.0  Small Market     1.0  Central
# 4239   Wisconsin            79.0      131.0  Small Market    -3.0  Central
# 4240   Wisconsin            87.0      165.0  Small Market     4.0  Central
#
#       Trade Product Type  Inventory
# ...

# %%
Sales_department.iloc [3000]
# Out:
# State                 Oklahoma
# Total Expenses           129.0
# New_Sales                264.0
# Market Size       Small Market
# Profit                    25.0
# Market                   South
# Trade                      100
# Product Type        Herbal Tea
# Inventory                665.0
# Name: 3001, dtype: object

# %%
Sales_department.drop(index=3002 ,inplace =True)

# %%
Sales_department.iloc[3002]
# Out:
# State                 Oklahoma
# Total Expenses           115.0
# New_Sales                224.0
# Market Size       Small Market
# Profit                    15.0
# Market                   South
# Trade                       85
# Product Type        Herbal Tea
# Inventory                694.0
# Name: 3004, dtype: object

# %%
Sales_department['NewColumn'] = ['Value1', 'Value2', 'Value3', 'Value4']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 Sales_department['NewColumn'] = ['Value1', 'Value2', 'Value3', 'Value4']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# -> 4143     value = self._sanitize_column(value)
#    4145     if (
#    4146         key in self.columns
#    4147         and value.ndim == 1
# ...

# %%
Data= [50 ,30,45,"ola",80.2]

# %%
pd.DataFrame(Data)
# Out:
#       0
# 0    50
# 1    30
# 2    45
# 3   ola
# 4  80.2

# %%
pd.DataFrame(Data, columns = ["Info"])
# Out:
#    Info
# 0    50
# 1    30
# 2    45
# 3   ola
# 4  80.2

# %%
Data_info=pd.DataFrame(Data, columns = ["Info"])

# %%
Data_info
# Out:
#    Info
# 0    50
# 1    30
# 2    45
# 3   ola
# 4  80.2

# %%
Data_info['profit'] = ['Value1', 'Value2', 'Value3', 'Value4','Value5']

# %%
Data_info
# Out:
#    Info  profit
# 0    50  Value1
# 1    30  Value2
# 2    45  Value3
# 3   ola  Value4
# 4  80.2  Value5

# %%
Data_info
# Out:
#    Info  profit
# 0    50  Value1
# 1    30  Value2
# 2    45  Value3
# 3   ola  Value4
# 4  80.2  Value5

# %%
New_row = {'info': 50, 'profit': 'Naira'}

# %%
Series = Data_info.append(New_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8656\2519093615.py in ?()
# ----> 1 Series = Data_info.append(New_row)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
Data_info.loc[len(Data_info)] = New_row

# %%
Data_info
# Out:
#    Info  profit
# 0    50  Value1
# 1    30  Value2
# 2    45  Value3
# 3   ola  Value4
# 4  80.2  Value5
# 5   NaN   Naira

# %%
len(Data_info)
# Out:
# 6
